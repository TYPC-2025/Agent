# %% [markdown]
# # 01_APIKEY_test

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(
    # 如果没有配置环境变量，请用阿里云百炼API Key替换：api_key="sk-xxx"
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    # ollama
    # base_url="http://localhost:11434/v1"
)

messages = [{"role": "user", "content": "用比喻解释区块链"}]
completion = client.chat.completions.create(
    model="qwen3-max",  # 您可以按需更换为其它深度思考模型
    messages=messages,
    extra_body={"enable_thinking": True},
    stream=True
)
is_answering = False  # 是否进入回复阶段
print("\n" + "=" * 20 + "思考过程" + "=" * 20)
for chunk in completion:
    delta = chunk.choices[0].delta
    if hasattr(delta, "reasoning_content") and delta.reasoning_content is not None:
        if not is_answering:
            print(delta.reasoning_content, end="", flush=True)
    if hasattr(delta, "content") and delta.content:
        if not is_answering:
            print("\n" + "=" * 20 + "完整回复" + "=" * 20)
            is_answering = True
        print(delta.content, end="", flush=True)
# Out:
# ====================思考过程====================
# 我们被问到：“用比喻解释区块链”。这是一个常见的问题，目的是让非技术背景的人理解区块链的核心概念。我们需要选择一个恰当的比喻，既要准确反映区块链的关键特性（如去中心化、不可篡改、分布式账本、共识机制等），又要通俗易懂。同时，要避免比喻的局限性导致误解。我们需要先列出区块链的关键特点，然后思考哪些比喻能覆盖这些特点。
#
# 关键特点：
# 1. 分布式账本：数据存储在多个节点上，而非单一中心。
# 2. 区块链结构：数据按时间顺序链接成链，每个区块包含前一个区块的哈希。
# 3. 不可篡改性：修改一个区块需要修改后续所有区块，且需要控制多数节点，难度极大。
# 4. 共识机制：节点通过某种规则（如工作量证明、权益证明）达成一致，确认交易有效性。
# 5. 透明性与匿名性：交易公开可查，但参与者身份可能匿名。
# 6. 去中心化：没有单一控制点，权力分散。
#
# 常见比喻：
# - 公共账本/共享账本：强调多人共同维护、透明。但可能让人联想到纸质账本，无法体现“链”和“不可篡改”。
# - 数字乐高：每个区块像乐高积木，拼接成链。但乐高可以拆开重拼，而区块链不可篡改，这个比喻可能不准确。
# - 公证处网络：多个公证处共同见证，但可能过于中心化。
# - 共享的Google文档：多人可查看编辑，但Google文档是中心化的（由Google服务器控制），且可以随意修改历史版本，不符合区块链的不可篡改性。这个比喻有缺陷，需谨慎。
# - 邮局寄信（带回执）：不太贴切。
# - 数字指纹链：强调哈希链接，但不够生活化。
#
# 最佳比喻之一：**“多人共同维护的公共记账本，每页盖章后无法修改，且每人手里都有一本完全相同的副本”**。但需要细化。
#
# 另一个经典比喻：**“数字世界的集体记忆”** 或 **“不可篡改的共享账本”**。
#
# 更生动的比喻：**“一群陌生人围坐一圈，每人面前有一本相同的账本。每当有新交易发生，大家共同验证并记录到当前页。当一页写满，所有人用密码学方法给这页生成唯一‘指纹’（哈希），并将指纹写在下一页开头。这样，任何试图篡改某页内容的行为都会导致后续所有页的指纹对不上，且因为每人手里都有完整副本，篡改者需要同时修改超过半数人的账本才能成功，几乎不可能。”**
#
# 这个比喻涵盖了：
# - 分布式（每人一本）
# - 区块（每页）
# - 链（指纹链接）
# - 共识（共同验证）
# - 不可篡改（指纹对不上）
# - 安全性（需修改多数副本）
#
# 但需要简化语言，使其更流畅。还可以加入“时间戳”概念。
#
# 另一个常见比喻是“数字琥珀”：将交易封存在透明的琥珀中，层层叠加，无法更改。但可能不够直观。
#
# 还可以用“接力赛跑”比喻：每个区块接力传递，但不太准确。
#
# 我们需要选择一个主比喻，并补充说明其与区块链特性的对应关系。同时，要指出比喻的局限性，避免误解。
#
# 结构建议：
# 1. 提出核心比喻（如“公共账本”或“集体记账”）。
# 2. 逐步解释比喻中的每个元素如何对应区块链技术。
# 3. 强调关键优势（去中心化、安全、透明）。
# 4. 简要说明比喻的不足（如现实中的账本可以撕掉，但区块链有密码学保护）。
# 5. 可选：对比其他不恰当的比喻，澄清误区。
#
# 注意：避免使用“比特币”作为比喻，因为区块链是底层技术，比特币是应用。但可以提及作为例子。
#
# 最终回答应简洁、生动、准确。目标读者可能是普通大众，所以语言要亲切。
#
# 让我们构思一个完整的回答：
#
# “想象一下，你和一群朋友（比如100个人）围坐在一张大桌子旁，每个人面前都放着一本完全相同的空白账本。你们约定：任何一个人发生的交易（比如‘小明付给小红10元’），都要大声宣布，然后所有人一起检查这笔交易是否合理（比如小明账户里是否有10元）。确认无误后，每个人都在自己账本的当前页工整地记下这笔交易。
#
# 当这一页写满后，大家暂停，一起用一个特殊的‘密码印章’给这一页盖上独一无二的印记（这个印记由本页所有内容生成，哪怕改动一个标点，印记就会完全不同）。接着，每个人把这页的印记抄写在下一页的开头，作为‘连接线索’。然后继续记录新交易。
#
# 这样，所有账本就形成了一条由‘印记’紧密链接的链条。如果有人想偷偷修改某一页的某笔交易（比如把‘10元’改成‘100元’），他不仅需要改掉自己账本的那一页，还要重新生成该页之后所有页的印记，并且必须同时篡改超过半数朋友的账本——这在现实中几乎不可能完成。因为每个人手里都有完整副本，任何不一致都会被立刻发现。
#
# 这个‘集体维护、密码链接、公开透明’的账本系统，就是区块链的核心思想：
# - **分布式**：100本账本分散在每个人手中，没有中心服务器。
# - **区块**：每一页就是一个‘区块’，包含一批交易。
# - **链**：每页的‘密码印记’（哈希值）像链条一样串起所有区块。
# - **共识机制**：大家共同验证交易，达成一致才记录。
# - **不可篡改**：修改历史需要颠覆整个链条和多数副本，成本极高。
# - **透明可信**：所有交易公开可查，信任建立在规则和集体监督上，而非某个权威机构。
#
# 当然，现实中的区块链用计算机和密码学自动完成这些步骤（比如‘密码印章’是哈希算法，‘集体验证’是工作量证明等共识算法），速度更快、规模更大。但这个比喻抓住了它‘去中心化信任’的灵魂——它让互不信任的陌生人，也能在无需中介的情况下安全协作。
#
# （小提示：有人用‘共享的Excel表格’比喻区块链，但Excel表格可以随意修改历史记录，且依赖中心服务器，这恰恰是区块链要解决的问题，所以这个比喻并不准确哦！）”
#
# 检查：
# - 是否覆盖关键点？是的。
# - 是否易懂？使用日常场景（朋友记账），语言生动。
# - 是否有误导？指出了比喻与现实的差异（计算机自动完成），并澄清了常见错误比喻。
# - 长度适中？可能稍长，但可以接受。可以适当精简。
#
# 还可以考虑更简短的版本，但用户要求“用比喻解释”，所以详细一点更好。
#
# 另一个角度：用“数字指纹链”比喻，但可能不够亲切。上述“集体账本”比喻是业界公认较好的。
#
# 确认：区块链不仅仅是账本，还可以存储其他数据，但账本比喻最适合解释其核心机制。对于初学者，聚焦在交易记录上是合适的。
#
# 最终回答应避免技术术语，如“哈希”可以称为“密码印章”或“数字指纹”，并在括号中简单说明。
#
# 优化语言：
# - 使用“你”来拉近距离。
# - 加入情感词，如“神奇的是”、“关键在于”。
#
# ====================完整回复====================
# 想象这样一个场景：
# 你和100位互不相识的陌生人围坐成圈，每人面前摊开一本**完全相同的空白账本**。你们约定：
# 🔹 任何交易（如“小明转给小红10元”）必须大声宣布；
# 🔹 所有人共同核对（小明余额是否足够？签名是否真实？）；
# 🔹 确认无误后，**每人同步在当前页工整记录**；
# 🔹 一页写满后，大家用“魔法印章”盖上**唯一数字指纹**（内容微变，指纹全变！），并将此指纹抄到下一页开头——像用密码锁把页面环环相扣；
# 🔹 新交易继续记在下一页，链条不断延伸。
#
# ✨ **神奇之处在于**：
# → 若有人偷偷涂改自己账本的某笔记录，他需瞬间重做该页之后所有“指纹”，并篡改超半数人的账本——在众人紧盯下几乎不可能！
# → 无人掌控全局：没有银行、没有管理员，信任源于**规则+集体监督**。
# → 每笔交易透明可查（账本公开），但参与者可用代号（保护隐私）。
#
# 📌 **对应区块链技术**：
# | 比喻元素 | 区块链实质 |
# |----------|------------|
# | 每人手中的账本 | 分布式节点（全球计算机副本） |
# | 一页记录 = 一个“区块” | 批量交易+时间戳+前页指纹 |
# | “魔法印章”的数字指纹 | 密码学哈希（如SHA-256） |
# | 集体核对规则 | 共识机制（PoW/PoS等） |
# | 篡改需改超半数账本 | 51%攻击理论难度极高 |
#
# 💡 **为什么这个比喻贴切？**
# 它抓住了区块链的**灵魂**：用技术实现“陌生人之间的可信协作”，把信任从“依赖权威”转向“依赖透明规则与数学”。
# （⚠️ 注意：现实中的区块链由计算机自动高速运行，无需人手抄写；且“账本”可存合同、证书等，不止金钱交易。）
#
# ❌ **常见误区澄清**：
# × “像共享Excel表格”——Excel可随意删改历史，且依赖中心服务器，**恰恰是区块链要解决的问题**！
# × “绝对匿名”——交易公开可追溯，匿名性取决于具体设计（如比特币是 pseudonymous）。
#
# 这个比喻或许不完美（现实有技术细节），但它点亮了核心：**区块链不是魔法，而是一套让世界更可信的“数字契约仪式”** 🌐✨

# %% [markdown]
# # 02_openai_use

# %%
from openai import OpenAI

client=OpenAI(
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)

response=client.chat.completions.create(
    model="qwen3-max",
    messages=[
        {"role":"system", "content": "你是一个Python编程专家，并且不说废话简单回答"},
        {"role":"assistant", "content": "好的，我是编程专家，并且话不多，你要问什么？"},
        {"role":"user", "content":"输出1-10的数字，使用Python代码"}
    ]
)
# 输出结果
print(response.choices[0].message.content)



# messages=[
#         {"role": "system", "content": "你是一个Python编程专家，并且不说废话简单回答"},
#         {"role": "assistant", "content": "好的，我是编程专家，并且话不多，你要问什么？"},
#         {"role": "user", "content":"输出1-10的数字，使用Python代码"}
#     ]
# Out:
# ```python
# for i in range(1, 11):
#     print(i)
# ```

# %% [markdown]
# # 03_OpenAI库的流式输出

# %%
from openai import OpenAI

client=OpenAI(
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)

response=client.chat.completions.create(
    model="qwen3-max",
    messages=[
        {"role":"system", "content": "你是一个Python编程专家，并且话非常多答"},
        {"role":"assistant", "content": "好的，我是编程专家，并且话很多，你要问什么？"},
        {"role":"user", "content":"输出1-10的数字，使用Python代码"}
    ],
    stream=True # 开启了流式输出的功能
)
# 输出结果
for chunk in response:
    print(
        chunk.choices[0].delta.content,
        end=" ",  #每一段之间以空格分隔
        flush=True  #立刻刷新缓冲区
    )


# messages=[
#         {"role": "system", "content": "你是一个Python编程专家，并且不说废话简单回答"},
#         {"role": "assistant", "content": "好的，我是编程专家，并且话不多，你要问什么？"},
#         {"role": "user", "content":"输出1-10的数字，使用Python代码"}
#     ]
# Out:
#  ``` python
# for  i in range(1,  11):
#     print (i)
# ```
